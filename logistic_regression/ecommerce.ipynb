# %%
import numpy as np

# Load data
import pandas as pd

# Visualize data
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# Split data
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Load and modify data

# %%
df = pd.read_csv('../data/ecommerce_data.csv')
df.head()
# Out:
#    is_mobile  n_products_viewed  visit_duration  is_returning_visitor  \
# 0          1                  0        0.657510                     0
# 1          1                  1        0.568571                     0
# 2          1                  0        0.042246                     1
# 3          1                  1        1.659793                     1
# 4          0                  1        2.014745                     1
#
#    time_of_day  user_action
# 0            3            0
# 1            2            1
# 2            1            0
# 3            1            2
# 4            1            2

# %%
# Only use 0 and 1 for user_action
df = df.drop(df[df['user_action'] > 1].index)

# %%
items = ['is_mobile', 'n_products_viewed', 'visit_duration', 'time_of_day']
X = df[items].copy()
Y = df['user_action'].copy()

# %%
# Normalize data
X['n_products_viewed'] = (X['n_products_viewed'] - X['n_products_viewed'].mean()) / X['n_products_viewed'].std()
X['visit_duration'] = (X['visit_duration'] - X['visit_duration'].mean()) / X['visit_duration'].std()

# %%
# Transform time_of_day to one hot encoding
X = X.join(pd.get_dummies(X['time_of_day']))
X = X.drop(['time_of_day'], axis = 1)

# %%
X.head()
# Out:
#    is_mobile  n_products_viewed  visit_duration    0    1    2    3
# 0          1          -0.673141       -0.274422  0.0  0.0  0.0  1.0
# 1          1           0.462072       -0.373996  0.0  0.0  1.0  0.0
# 2          1          -0.673141       -0.963261  0.0  1.0  0.0  0.0
# 6          0          -0.673141        0.602007  0.0  1.0  0.0  0.0
# 7          1          -0.673141       -0.971082  0.0  0.0  0.0  1.0

# %%
features_train, features_test, labels_train, labels_test = train_test_split(X, Y, test_size = 0.3)

# %% [markdown]
# # Logistic regression

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# %%
def feed_foward(X, W, b):
    return sigmoid(X.dot(W) + b)

# %%
def accuracy(Y, pred):
    return np.mean(Y == pred)

# %%
def cross_entropy(T, pred):
    return -np.mean(T*np.log(pred) + (1 - T)*np.log(1 - pred))

# %%
W = np.random.randn(X.shape[1])
b = 0

# %%
logits = feed_foward(X, W, b)
predictions = np.round(logits)

# %%
accuracy(Y, predictions)
# Out:
# 0.61306532663316582

# %%
training_costs = []
test_costs = []

# Hyperparameters
n_interations = 10000
learning_rate = 3e-4
regularization = 0.1

# %%
for i in range(n_interations):
    # Predict train and test
    predict_train = feed_foward(features_train, W, b)
    predict_test = feed_foward(features_test, W, b)
    
    # Perform gradient descent, and use regularization     
    W -= learning_rate * ((predict_train - labels_train).dot(features_train) - regularization * W)
    b -= learning_rate * (predict_train - labels_train).sum()
    
    # Calculate costs
    training_cost = cross_entropy(labels_train, predict_train)
    training_costs.append(training_cost)
    test_cost = cross_entropy(labels_test, predict_test)
    test_costs.append(test_cost)
    
    # Calculate accuracy
    if i % 100 == 0:
        print('Cross entropy (Mean): ', training_cost)
        print('Accuracy on train:', accuracy(labels_train, np.round(predict_train)))  
        print('Accuracy on test:', accuracy(labels_test, np.round(predict_test)))
        print('-------------------------')
# Out:
# Cross entropy (Mean):  0.8364792704703987
# Accuracy on train: 0.615107913669
# Accuracy on test: 0.608333333333
# -------------------------
# Cross entropy (Mean):  0.3124231762822998
# Accuracy on train: 0.852517985612
# Accuracy on test: 0.875
# -------------------------
# Cross entropy (Mean):  0.26284650342100135
# Accuracy on train: 0.942446043165
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.2451800307268934
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.23605553168205123
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.23062135533380743
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.22709863879523826
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.22467670029606268
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.22293624865309253
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.22164113760263815
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.22064988811610367
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.21987358442601893
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.2192541077267597
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.21875216527768276
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.21834038527755098
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.975
# -------------------------
# Cross entropy (Mean):  0.21799917855605572
# Accuracy on train: 0.964028776978
# Accuracy on test: 0.966666666667
# -------------------------
# Cross entropy (Mean):  0.2177141777829289
# Accuracy on train: 0.964028776978
# Accuracy on test: 0.958333333333
# -------------------------
# Cross entropy (Mean):  0.21747460816678246
# Accuracy on train: 0.964028776978
# Accuracy on test: 0.95
# -------------------------
# Cross entropy (Mean):  0.21727222469662452
# Accuracy on train: 0.964028776978
# Accuracy on test: 0.941666666667
# -------------------------
# Cross entropy (Mean):  0.2171006029580291
# Accuracy on train: 0.964028776978
# Accuracy on test: 0.941666666667
# -------------------------
# Cross entropy (Mean):  0.2169546557475104
# Accuracy on train: 0.964028776978
# Accuracy on test: 0.933333333333
# -------------------------
# Cross entropy (Mean):  0.2168302969362047
# Accuracy on train: 0.964028776978
# Accuracy on test: 0.933333333333
# -------------------------
# Cross entropy (Mean):  0.21672420323746522
# Accuracy on train: 0.964028776978
# Accuracy on test: 0.933333333333
# -------------------------
# Cross entropy (Mean):  0.21663364226393433
# Accuracy on train: 0.964028776978
# Accuracy on test: 0.933333333333
# -------------------------
# Cross entropy (Mean):  0.21655634625069436
# Accuracy on train: 0.964028776978
# Accuracy on test: 0.933333333333
# -------------------------
# Cross entropy (Mean):  0.2164904177633525
# Accuracy on train: 0.964028776978
# Accuracy on test: 0.933333333333
# -------------------------
# Cross entropy (Mean):  0.21643425817064096
# Accuracy on train: 0.964028776978
# Accuracy on test: 0.933333333333
# -------------------------
# Cross entropy (Mean):  0.21638651257319025
# Accuracy on train: 0.964028776978
# Accuracy on test: 0.933333333333
# -------------------------
# Cross entropy (Mean):  0.21634602680933626
# Accuracy on train: 0.964028776978
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21631181345491948
# Accuracy on train: 0.964028776978
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21628302461635987
# Accuracy on train: 0.964028776978
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21625892992467005
# Accuracy on train: 0.964028776978
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21623889856285067
# Accuracy on train: 0.964028776978
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.2162223844593039
# Accuracy on train: 0.964028776978
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21620891399467018
# Accuracy on train: 0.964028776978
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21619807572494795
# Accuracy on train: 0.964028776978
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21618951173766338
# Accuracy on train: 0.964028776978
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21618291034228895
# Accuracy on train: 0.964028776978
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.2161779998594131
# Accuracy on train: 0.964028776978
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21617454332117705
# Accuracy on train: 0.964028776978
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.2161723339323431
# Accuracy on train: 0.964028776978
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21617119116986722
# Accuracy on train: 0.964028776978
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21617095742122253
# Accuracy on train: 0.964028776978
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.2161714950793744
# Accuracy on train: 0.964028776978
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21617268402641532
# Accuracy on train: 0.964028776978
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21617441944920138
# Accuracy on train: 0.964028776978
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21617660993952925
# Accuracy on train: 0.964028776978
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21617917583890997
# Accuracy on train: 0.964028776978
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21618204779417624
# Accuracy on train: 0.964028776978
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21618516549524597
# Accuracy on train: 0.964028776978
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.2161884765706524
# Accuracy on train: 0.964028776978
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21619193561996158
# Accuracy on train: 0.964028776978
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21619550336520843
# Accuracy on train: 0.964028776978
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21619914590599365
# Accuracy on train: 0.964028776978
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.2162028340649911
# Accuracy on train: 0.964028776978
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21620654281245205
# Accuracy on train: 0.964028776978
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21621025075981262
# Accuracy on train: 0.964028776978
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.2162139397138248
# Accuracy on train: 0.964028776978
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21621759428377652
# Accuracy on train: 0.964028776978
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21622120153531088
# Accuracy on train: 0.964028776978
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21622475068520242
# Accuracy on train: 0.964028776978
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21622823283216439
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21623164071937725
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.2162349685249654
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21623821167713067
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21624136669102673
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.2162444310248495
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21624740295288786
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21625028145357758
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21625306611081754
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21625575702701574
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21625835474652777
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21626086018827972
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21626327458652994
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21626559943884424
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.2162678364604461
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.2162699875442188
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.2162720547257222
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.2162740401526314
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21627594605810402
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21627777473762402
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21627952852891166
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21628120979455867
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.2162828209070625
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21628436423598368
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21628584213697977
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21628725694248907
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21628861095387483
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21628990643485288
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21629114560604074
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21629233064050546
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21629346366017738
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21629454673301782
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.2162955818708595
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21629657102781977
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21629751609921619
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.2162984189209207
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21629928126908582
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21630010486019738
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.925
# -------------------------
# Cross entropy (Mean):  0.21630089135140063
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.925
# -------------------------

# %%
plt.plot(training_costs, c = 'b', label = 'Train cost')
plt.plot(test_costs, c = 'g', label = 'Test cost')
plt.legend()
