# %%
import numpy as np

# Load data
import pandas as pd

# Visualize data
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# Split data
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Load and modify data

# %%
df = pd.read_csv('data/ecommerce_data.csv')
df.head()
# Out:
#    is_mobile  n_products_viewed  visit_duration  is_returning_visitor  \
# 0          1                  0        0.657510                     0
# 1          1                  1        0.568571                     0
# 2          1                  0        0.042246                     1
# 3          1                  1        1.659793                     1
# 4          0                  1        2.014745                     1
#
#    time_of_day  user_action
# 0            3            0
# 1            2            1
# 2            1            0
# 3            1            2
# 4            1            2

# %%
# Only use 0 and 1 for user_action
df = df.drop(df[df['user_action'] > 1].index)

# %%
items = ['is_mobile', 'n_products_viewed', 'visit_duration', 'time_of_day']
X = df[items].copy()
Y = df['user_action'].copy()

# %%
# Normalize data
X['n_products_viewed'] = (X['n_products_viewed'] - X['n_products_viewed'].mean()) / X['n_products_viewed'].std()
X['visit_duration'] = (X['visit_duration'] - X['visit_duration'].mean()) / X['visit_duration'].std()

# %%
# Transform time_of_day to one hot encoding
X = X.join(pd.get_dummies(X['time_of_day']))
X = X.drop(['time_of_day'], axis = 1)

# %%
X.head()
# Out:
#    is_mobile  n_products_viewed  visit_duration    0    1    2    3
# 0          1          -0.673141       -0.274422  0.0  0.0  0.0  1.0
# 1          1           0.462072       -0.373996  0.0  0.0  1.0  0.0
# 2          1          -0.673141       -0.963261  0.0  1.0  0.0  0.0
# 6          0          -0.673141        0.602007  0.0  1.0  0.0  0.0
# 7          1          -0.673141       -0.971082  0.0  0.0  0.0  1.0

# %%
features_train, features_test, labels_train, labels_test = train_test_split(X, Y, test_size = 0.3)

# %% [markdown]
# # Logistic regression

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# %%
def feed_foward(X, W, b):
    return sigmoid(X.dot(W) + b)

# %%
def accuracy(Y, pred):
    return np.mean(Y == pred)

# %%
def cross_entropy(T, pred):
    return -np.mean(T*np.log(pred) + (1 - T)*np.log(1 - pred))

# %%
W = np.random.randn(X.shape[1])
b = 0

# %%
logits = feed_foward(X, W, b)
predictions = np.round(logits)

# %%
accuracy(Y, predictions)
# Out:
# 0.3165829145728643

# %%
training_costs = []
test_costs = []

# Hyperparameters
n_interations = 10000
learning_rate = 3e-4
regularization = 0.1

# %%
for i in range(n_interations):
    # Predict train and test
    predict_train = feed_foward(features_train, W, b)
    predict_test = feed_foward(features_test, W, b)
    
    # Perform gradient descent, and use regularization     
    W -= learning_rate * ((predict_train - labels_train).dot(features_train) - regularization * W)
    b -= learning_rate * (predict_train - labels_train).sum()
    
    # Calculate costs
    training_cost = cross_entropy(labels_train, predict_train)
    training_costs.append(training_cost)
    test_cost = cross_entropy(labels_test, predict_test)
    test_costs.append(test_cost)
    
    # Calculate accuracy
    if i % 100 == 0:
        print('Cross entropy (Mean): ', training_cost)
        print('Accuracy on train:', accuracy(labels_train, np.round(predict_train)))  
        print('Accuracy on test:', accuracy(labels_test, np.round(predict_test)))
        print('-------------------------')
# Out:
# Cross entropy (Mean):  1.1372082376298693
# Accuracy on train: 0.305755395683
# Accuracy on test: 0.341666666667
# -------------------------
# Cross entropy (Mean):  0.3383636361747582
# Accuracy on train: 0.884892086331
# Accuracy on test: 0.875
# -------------------------
# Cross entropy (Mean):  0.26925578798717165
# Accuracy on train: 0.906474820144
# Accuracy on test: 0.916666666667
# -------------------------
# Cross entropy (Mean):  0.2443423636389776
# Accuracy on train: 0.953237410072
# Accuracy on test: 0.95
# -------------------------
# Cross entropy (Mean):  0.23187560771880106
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.2246303291418665
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.2200181570638818
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.21689200039562068
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.21467307701887314
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.21304147892290548
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.21180775581976025
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.21085347893162873
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.21010134980849526
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20949911970816146
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20901043644243683
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20860938123691947
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20827707659290845
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.2079995101757843
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20776610055104971
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20756873013980154
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.2074010803104765
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20725816622847706
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.2071360063045308
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20703138386042863
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20694167293023388
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20686470928547146
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20679869376206533
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20674211894112876
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.2066937129108364
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20665239566074992
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.2066172449188449
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.2065874691200797
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.2065623858150448
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20654140426869835
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20652401131676587
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20650975977786942
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20649825888829554
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20648916635095163
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20648218168299906
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20647704061633315
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20647351035790068
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.2064713855570894
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20647048485838887
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20647064794149475
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.2064717329696995
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.206473614382161
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20647618097721523
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20647933424320544
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.206482986900708
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.206487061626049
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20649148993086633
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20649621117647113
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20650117170501253
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20650632407216765
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.2065116263683252
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.2065170416170896
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.2065225372415203
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.2065280845898393
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20653365851344216
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.2065392369910287
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20654480079345
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.2065503331845724
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.2065558196540522
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20656124767843104
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.2065666065073799
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20657188697233358
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20657708131505872
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20658218303400805
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20658718674654084
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20659208806534007
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.2065968834875108
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.206601570295046
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.2066061464654674
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20661061059160254
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20661496180954833
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20661919973399465
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20662332440015313
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.2066273362116368
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20663123589367868
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20663502445116183
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20663870313098298
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20664227338831323
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20664573685637783
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20664909531939057
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.2066523506883643
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20665550497946994
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20665856029473534
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20666151880482353
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20666438273370963
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20666715434504707
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20666983593007565
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.206672429796915
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20667493826109878
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20667736363723227
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20667970823167317
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20668197433610933
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20668416422196917
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20668628013556803
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20668832429391093
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------
# Cross entropy (Mean):  0.20669029888110627
# Accuracy on train: 0.960431654676
# Accuracy on test: 0.983333333333
# -------------------------

# %%
plt.plot(training_costs, c = 'b', label = 'Train cost')
plt.plot(test_costs, c = 'g', label = 'Test cost')
plt.legend()
